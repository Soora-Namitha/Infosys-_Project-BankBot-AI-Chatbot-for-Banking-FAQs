# %%
print("hello world")
# Out:
# hello world

# %%
pip install matplotlib pandas
# Out:
# ...
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      -------------- ----------------------- 20.5/52.8 kB 165.2 kB/s eta 0:00:01
#      -------------- ----------------------- 20.5/52.8 kB 165.2 kB/s eta 0:00:01
#      -------------- ----------------------- 20.5/52.8 kB 165.2 kB/s eta 0:00:01
#      ------------------------------------ - 51.2/52.8 kB 175.0 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 170.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/116.4 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/116.4 kB ? eta -:--:--
#      -------------------- ------------------ 61.4/116.4 kB 1.1 MB/s eta 0:00:01
# ...
